# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from os import listdir, remove
from os.path import isfile, join
import shutil
from pathlib import Path

# %%
path = '/home/hyperdog/octo/logs/'
onlyfiles = [f for f in listdir(path) if isfile(join(path, f))]
print(len(onlyfiles))
# Out:
# 1

# %%
data = np.load(path + onlyfiles[0], allow_pickle=True)
plt.plot(data)

# %%
plt.plot([step['state'][:6] for step in data]) # joint angles
# plt.plot([step['state'][6:9] for step in data]) # x, y, z
# plt.plot([step['state'][9:12] for step in data]) # rx, ry, rz
# plt.plot([step['state'][12] for step in data]) # gripper pose
# plt.plot([step['state'][13] for step in data]) # force
# Out:
# [<matplotlib.lines.Line2D at 0x7af1ca59f280>,
#  <matplotlib.lines.Line2D at 0x7af1ca572230>,
#  <matplotlib.lines.Line2D at 0x7af1ca5723e0>,
#  <matplotlib.lines.Line2D at 0x7af1ca554820>,
#  <matplotlib.lines.Line2D at 0x7af1ca556f20>,
#  <matplotlib.lines.Line2D at 0x7af1cabfd360>]
